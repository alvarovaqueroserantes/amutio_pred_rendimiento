# %%
import pandas as pd
import numpy as np

np.random.seed(42)

# generar 10 parcelas por variedad
variedades = {
    "Agria": {"mes_siembra": 2, "ciclo_semanas": 18},
    "Monalisa": {"mes_siembra": 1, "ciclo_semanas": 16},
    "Spunta": {"mes_siembra": 12, "ciclo_semanas": 15}
}

parcelas = {}
for variedad, vinfo in variedades.items():
    for i in range(1, 11):
        parcela_id = f"{variedad}_p{i}"
        parcelas[parcela_id] = {
            "variedad": variedad,
            "tam_ha": np.random.uniform(2,4),
            "ciclo_semanas": vinfo["ciclo_semanas"],
            "mes_siembra": vinfo["mes_siembra"]
        }

# fechas semanales
fechas = pd.date_range("2020-07-01", "2025-07-01", freq="W")

data_semanal = []
data_cosechas = []

for parcela, info in parcelas.items():
    variedad = info["variedad"]
    tam_ha = info["tam_ha"]
    ciclo_semanas = info["ciclo_semanas"]
    mes_siembra = info["mes_siembra"]
    
    rendimiento_acumulado = 0
    semana_cultivo = 0
    
    for fecha in fechas:
        mes_actual = fecha.month
        semana_del_año = fecha.isocalendar().week
        
        # iniciar campaña anual
        if mes_actual == mes_siembra and semana_cultivo == 0:
            semana_cultivo = 1
            rendimiento_acumulado = 0
            
        if semana_cultivo > 0:
            # clima según época
            if mes_actual in [12,1,2]:
                temp_media = np.random.normal(13,2)
                lluvia = np.clip(np.random.normal(20,10), 0, 50)
                riego = np.clip(np.random.normal(300,50), 150,450)
            elif mes_actual in [3,4,5]:
                temp_media = np.random.normal(17,3)
                lluvia = np.clip(np.random.normal(15,8), 0,40)
                riego = np.clip(np.random.normal(400,70), 250,550)
            elif mes_actual in [6,7,8]:
                temp_media = np.random.normal(27,3)
                lluvia = np.clip(np.random.normal(5,3), 0,15)
                riego = np.clip(np.random.normal(600,80), 400,800)
            else:
                temp_media = np.random.normal(20,3)
                lluvia = np.clip(np.random.normal(15,10), 0,50)
                riego = np.clip(np.random.normal(400,70), 250,550)
            
            # fertilizante
            if semana_cultivo <= 4:
                fertilizante = np.clip(np.random.normal(10,2),5,15)
            else:
                fertilizante = np.clip(np.random.normal(5,1.5),2,8)
            
            # rendimiento
            rendimiento_acumulado += (
                0.3 * fertilizante +
                0.05 * riego/100 +
                np.clip(temp_media - 15, 0, 10)*0.4 -
                0.1 * (30 - lluvia)/30
            )
            
            data_semanal.append({
                "fecha": fecha,
                "mes": mes_actual,
                "semana_del_año": semana_del_año,
                "parcela": parcela,
                "variedad": variedad,
                "tam_parcela_ha": tam_ha,
                "temp_media": temp_media,
                "lluvia": lluvia,
                "fertilizante": fertilizante,
                "riego": riego,
                "semana_cultivo": semana_cultivo
            })
            
            semana_cultivo += 1
            
            if semana_cultivo > ciclo_semanas:
                # fijar mes de cosecha según variedad
                if variedad == "Agria":
                    mes_cosecha = 6  # junio
                elif variedad == "Monalisa":
                    mes_cosecha = 5  # mayo
                elif variedad == "Spunta":
                    mes_cosecha = 4  # abril
                else:
                    mes_cosecha = fecha.month  # fallback

                rendimiento_ciclo = 25 + rendimiento_acumulado + np.random.normal(0,2)
                
                data_cosechas.append({
                    "fecha_cosecha": fecha,
                    "parcela": parcela,
                    "variedad": variedad,
                    "tam_parcela_ha": tam_ha,
                    "rendimiento_ton_ha": np.round(rendimiento_ciclo,2),
                    "mes_cosecha": mes_cosecha
                })
                
                semana_cultivo = 0  # parar ciclo hasta siguiente año

# dataframes
df_semanal = pd.DataFrame(data_semanal)
df_cosechas = pd.DataFrame(data_cosechas)

# guardar
df_semanal.to_csv("datos_semanales.csv", index=False)
df_cosechas.to_csv("datos_cosechas.csv", index=False)

print("\nPrimeras filas SEMANAL:")
print(df_semanal.head(10))

print("\nPrimeras filas COSECHAS:")
print(df_cosechas.head(10))


import pandas as pd
import numpy as np

np.random.seed(42)

# cargar histórico
historico = pd.read_csv("datos_semanales.csv", parse_dates=["fecha"])

fecha_max = historico["fecha"].max()
fechas_futuras = pd.date_range(fecha_max + pd.Timedelta(days=1), periods=28, freq="D")

parcelas = historico["parcela"].unique()

futuro = []

for parcela in parcelas:
    variedad = historico[historico["parcela"]==parcela]["variedad"].iloc[-1]
    tam_parcela = historico[historico["parcela"]==parcela]["tam_parcela_ha"].iloc[-1]
    
    for fecha in fechas_futuras:
        mes = fecha.month
        
        # temperatura
        if mes in [12,1,2]:
            temp_max = np.random.normal(17,2)
            temp_min = np.random.normal(8,2)
        elif mes in [6,7,8]:
            temp_max = np.random.normal(32,3)
            temp_min = np.random.normal(20,2)
        else:
            temp_max = np.random.normal(24,3)
            temp_min = np.random.normal(12,2)
        temp_media = (temp_max + temp_min) / 2
        
        # lluvia
        lluvia = np.clip(np.random.normal(2,2), 0,20)
        prob_lluvia = np.clip(np.random.normal(30,10), 0,100)
        
        # humedad
        humedad_rel = np.clip(np.random.normal(65,10),30,100)
        
        # viento
        viento_vel = np.clip(np.random.normal(15,5),0,40)
        viento_dir = np.random.randint(0,360)
        
        # radiación solar
        radiacion = np.clip(np.random.normal(15,5),5,30)  # MJ/m2/día
        
        # presión
        presion = np.clip(np.random.normal(1013,5),1000,1030)
        
        # ET0
        et0 = np.clip(np.random.normal(4,1),2,8)
        
        # sugerencias riego/ferti
        if temp_media > 25:
            riego_sug = np.clip(np.random.normal(25,5),15,35)
            ferti_sug = np.clip(np.random.normal(0.5,0.1),0.3,0.7)
        else:
            riego_sug = np.clip(np.random.normal(15,4),5,25)
            ferti_sug = np.clip(np.random.normal(0.3,0.05),0.1,0.5)
        
        futuro.append({
            "fecha": fecha,
            "parcela": parcela,
            "variedad": variedad,
            "tam_parcela_ha": tam_parcela,
            "temp_max": temp_max,
            "temp_min": temp_min,
            "temp_media": temp_media,
            "lluvia": lluvia,
            "prob_lluvia_%": prob_lluvia,
            "humedad_relativa_%": humedad_rel,
            "viento_vel_kmh": viento_vel,
            "viento_dir_deg": viento_dir,
            "radiacion_MJ_m2": radiacion,
            "presion_hPa": presion,
            "et0_mm": et0,
            "riego_sugerido_mm": riego_sug,
            "fertilizante_sugerido_kg": ferti_sug
        })
        
df_futuro = pd.DataFrame(futuro)
df_futuro.to_csv("prediccion_meteo_4semanas_completa.csv", index=False)

print("✅ CSV `prediccion_meteo_4semanas_completa.csv` generado con variables meteorológicas extendidas día a día.")
# Out:
# Primeras filas SEMANAL:
#        fecha  mes  semana_del_año   parcela variedad  tam_parcela_ha  \
# 0 2021-02-07    2               5  Agria_p1    Agria         2.74908
# 1 2021-02-14    2               6  Agria_p1    Agria         2.74908
# 2 2021-02-21    2               7  Agria_p1    Agria         2.74908
# 3 2021-02-28    2               8  Agria_p1    Agria         2.74908
# 4 2021-03-07    3               9  Agria_p1    Agria         2.74908
# 5 2021-03-14    3              10  Agria_p1    Agria         2.74908
# 6 2021-03-21    3              11  Agria_p1    Agria         2.74908
# 7 2021-03-28    3              12  Agria_p1    Agria         2.74908
# 8 2021-04-04    4              13  Agria_p1    Agria         2.74908
# 9 2021-04-11    4              14  Agria_p1    Agria         2.74908
#
#    temp_media     lluvia  fertilizante       riego  semana_cultivo
# 0   10.698013  23.756980      9.416613  269.968066               1
# 1   11.796587  38.522782      7.884578  299.325139               2
# 2   14.645090   7.791564      6.080660  310.443180               3
# 3   10.343628  21.968612     10.342737  336.923329               4
# 4   16.653055  12.591170      3.920234  296.503461               5
# 5   15.618084  23.456978      2.355440  424.053280               6
# 6   17.972252  11.919342      5.917514  352.615460               7
# 7   20.092999  22.450241      4.536181  341.254773               8
# 8   17.993790  22.804361      4.721512  366.457803               9
# 9   13.680995   5.430347      7.034360  456.876808              10
#
# Primeras filas COSECHAS:
#   fecha_cosecha   parcela variedad  tam_parcela_ha  rendimiento_ton_ha  \
# 0    2021-06-06  Agria_p1    Agria        2.749080               76.29
# 1    2022-06-05  Agria_p1    Agria        2.749080               72.06
# 2    2023-06-04  Agria_p1    Agria        2.749080               76.38
# 3    2024-06-02  Agria_p1    Agria        2.749080               77.39
# 4    2025-06-01  Agria_p1    Agria        2.749080               79.43
# 5    2021-06-06  Agria_p2    Agria        3.901429               72.30
# 6    2022-06-05  Agria_p2    Agria        3.901429               72.41
# 7    2023-06-04  Agria_p2    Agria        3.901429               78.15
# 8    2024-06-02  Agria_p2    Agria        3.901429               78.18
# 9    2025-06-01  Agria_p2    Agria        3.901429               82.33
#
#    mes_cosecha
# 0            6
# 1            6
# 2            6
# 3            6
# 4            6
# 5            6
# 6            6
# 7            6
# 8            6
# 9            6
# ✅ CSV `prediccion_meteo_4semanas_completa.csv` generado con variables meteorológicas extendidas día a día.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split, GroupKFold, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import StackingRegressor, RandomForestRegressor
from sklearn.linear_model import Ridge
import xgboost as xgb
import lightgbm as lgb

warnings.filterwarnings("ignore")

# ------------------------------------------------------------
# 1. Cargar datos
# ------------------------------------------------------------
semanal = pd.read_csv("datos_semanales.csv", parse_dates=["fecha"])
cosechas = pd.read_csv("datos_cosechas.csv", parse_dates=["fecha_cosecha"])

# ------------------------------------------------------------
# 2. Ingeniería de variables ciclo a ciclo
# ------------------------------------------------------------
features_ciclos = []

for parcela in semanal['parcela'].unique():
    datos_parcela = semanal[semanal['parcela'] == parcela].copy()
    datos_parcela = datos_parcela.sort_values("fecha")
    
    ciclos = datos_parcela.groupby((datos_parcela['semana_cultivo'] == 1).cumsum())
    
    for i, grupo in ciclos:
        fecha_cosecha = grupo['fecha'].max()
        variedad = grupo['variedad'].iloc[0]
        tam_parcela_ha = grupo['tam_parcela_ha'].iloc[0]
        
        temp_media = grupo['temp_media'].mean()
        temp_std = grupo['temp_media'].std()
        lluvia_total = grupo['lluvia'].sum()
        fertilizante_total = grupo['fertilizante'].sum()
        fertilizante_medio = grupo['fertilizante'].mean()
        riego_total = grupo['riego'].sum()
        riego_medio = grupo['riego'].mean()
        
        match = cosechas[
            (cosechas['parcela'] == parcela) & 
            (cosechas['fecha_cosecha'] == fecha_cosecha)
        ]
        if not match.empty:
            rendimiento = match['rendimiento_ton_ha'].iloc[0]
            
            features_ciclos.append({
                "parcela": parcela,
                "variedad": variedad,
                "tam_parcela_ha": tam_parcela_ha,
                "temp_media": temp_media,
                "temp_std": temp_std,
                "lluvia_total": lluvia_total,
                "fertilizante_total": fertilizante_total,
                "fertilizante_medio": fertilizante_medio,
                "riego_total": riego_total,
                "riego_medio": riego_medio,
                "rendimiento_ton_ha": rendimiento,
                "mes_cosecha": fecha_cosecha.month
            })

df = pd.DataFrame(features_ciclos)
df['variedad_code'] = df['variedad'].astype('category').cat.codes

# ------------------------------------------------------------
# 3. Definir X e y
# ------------------------------------------------------------
X = df[
    [
        "variedad_code", 
        "tam_parcela_ha",
        "temp_media", 
        "temp_std",
        "lluvia_total", 
        "fertilizante_total",
        "fertilizante_medio",
        "riego_total", 
        "riego_medio", 
        "mes_cosecha"
    ]
]
y = df["rendimiento_ton_ha"]

# grupos para cross-validation (usando parcela)
groups = df["parcela"]

# ------------------------------------------------------------
# 4. Stacking Ensemble avanzado
# ------------------------------------------------------------
base_learners = [
    ('xgb', xgb.XGBRegressor(objective="reg:squarederror", random_state=42)),
    ('rf', RandomForestRegressor(random_state=42)),
    ('lgb', lgb.LGBMRegressor(random_state=42))
]
meta_learner = Ridge()

stacked = StackingRegressor(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=5,
    n_jobs=-1
)

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('stack', stacked)
])

param_grid = {
    'stack__final_estimator__alpha': [0.1, 1.0, 10.0],
}

gkf = GroupKFold(n_splits=5)

grid = GridSearchCV(
    pipeline,
    param_grid=param_grid,
    cv=gkf.split(X, y, groups=groups),
    scoring="r2",
    n_jobs=-1
)

# ------------------------------------------------------------
# 5. Entrenamiento
# ------------------------------------------------------------
grid.fit(X, y)

print("Mejores parámetros Stacking:")
print(grid.best_params_)
print(f"Mejor R2 validación cruzada: {grid.best_score_:.3f}")

# ------------------------------------------------------------
# 6. Evaluación holdout
# ------------------------------------------------------------
X_train, X_test, y_train, y_test, groups_train, groups_test = train_test_split(
    X, y, groups, test_size=0.2, random_state=42
)
best_model = grid.best_estimator_
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print(f"RMSE holdout: {rmse:.2f}")
print(f"R2 holdout: {r2:.2f}")

# ------------------------------------------------------------
# 7. Importancia de variables del XGB base
# ------------------------------------------------------------
# sacamos la importancia del primer learner (XGB)
booster = best_model.named_steps['stack'].estimators_[0]
importances = booster.feature_importances_
feat_names = X.columns
sorted_idx = np.argsort(importances)

plt.figure(figsize=(8,6))
plt.barh(feat_names[sorted_idx], importances[sorted_idx], color="#91c7ae")
plt.title("Importancia de Variables (XGB base en Stacking)")
plt.xlabel("Importancia")
plt.tight_layout()
plt.show()
# Out:
# Mejores parámetros Stacking:
# {'stack__final_estimator__alpha': 10.0}
# Mejor R2 validación cruzada: 0.923
# RMSE holdout: 2.51
# R2 holdout: 0.93
#   File "c:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 550, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1028, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1540, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
import joblib

# exportar el stacking completo
joblib.dump(best_model, "data/modelo_stack.pkl")
print("✅ Modelo guardado en modelo_stack.pkl")
# Out:
# ✅ Modelo guardado en modelo_stack.pkl

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd

# cargar semanal
df = pd.read_csv("datos_semanales.csv", parse_dates=["fecha"])
df_cosechas = pd.read_csv("datos_cosechas.csv", parse_dates=["fecha_cosecha"])

features = ["temp_media", "lluvia", "fertilizante", "riego"]

X_seq = []
y_seq = []

for parcela in df["parcela"].unique():
    datos_parcela = df[df["parcela"] == parcela].sort_values("fecha")
    ciclos = datos_parcela.groupby((datos_parcela['semana_cultivo'] == 1).cumsum())

    for _, grupo in ciclos:
        seq = grupo[features].values
        if len(seq) < 12:
            continue
        seq = seq[:12]
        
        # generar el target como rendimiento acumulado simulado por semana
        cosecha = df_cosechas[
            (df_cosechas["parcela"] == parcela) &
            (df_cosechas["fecha_cosecha"] == grupo["fecha"].max())
        ]
        if not cosecha.empty:
            total_rend = cosecha["rendimiento_ton_ha"].iloc[0]
            # distribuimos de forma lineal como ejemplo
            y_vector = np.linspace(total_rend/12, total_rend, 12)
            X_seq.append(seq)
            y_seq.append(y_vector)

X_seq = np.array(X_seq)
y_seq = np.array(y_seq)

# normalizar
scaler = MinMaxScaler()
n_samples, n_steps, n_features = X_seq.shape
X_seq_reshape = X_seq.reshape(-1, n_features)
X_seq_norm = scaler.fit_transform(X_seq_reshape)
X_seq_norm = X_seq_norm.reshape(n_samples, n_steps, n_features)

# --------------------------------------------------
# modelo LSTM
# --------------------------------------------------
model = models.Sequential([
    layers.LSTM(64, input_shape=(12, len(features)), return_sequences=True),
    layers.TimeDistributed(layers.Dense(16, activation="relu")),
    layers.TimeDistributed(layers.Dense(1))
])
model.compile(optimizer="adam", loss="mse", metrics=["mae"])

history = model.fit(
    X_seq_norm, y_seq.reshape(n_samples, n_steps, 1),
    epochs=200,
    batch_size=16,
    validation_split=0.2
)

model.save("data/modelo_lstm.h5")
print("✅ LSTM secuencial guardado en modelo_lstm_semanal.h5")
# Out:
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 1788.2239 - mae: 37.0290 - val_loss: 1230.1869 - val_mae: 30.8985
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1746.1387 - mae: 36.5509 - val_loss: 1181.7542 - val_mae: 30.2737
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1667.5857 - mae: 35.7581 - val_loss: 1044.3304 - val_mae: 28.5516
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1463.1919 - mae: 33.5376 - val_loss: 828.7862 - val_mae: 25.4461
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1249.9640 - mae: 30.8798 - val_loss: 631.5293 - val_mae: 21.9449
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 982.4667 - mae: 27.0055 - val_loss: 469.1302 - val_mae: 18.4232
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 759.0137 - mae: 23.1931 - val_loss: 343.6118 - val_mae: 15.0616
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 617.0750 - mae: 20.1351 - val_loss: 251.3409 - val_mae: 11.9763
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 475.5816 - mae: 16.8721 - val_loss: 185.9165 - val_mae: 9.8740
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 388.3796 - mae: 14.5281 - val_loss: 141.7605 - val_mae: 8.8014
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 294.4657 - mae: 12.2829 - val_loss: 114.4862 - val_mae: 8.1939
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 261.6643 - mae: 11.5789 - val_loss: 100.0683 - val_mae: 7.9788
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 234.2001 - mae: 11.0847 - val_loss: 94.9518 - val_mae: 7.9528
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 195.5663 - mae: 10.3458 - val_loss: 95.0166 - val_mae: 8.0169
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 181.3129 - mae: 10.0706 - val_loss: 96.9423 - val_mae: 8.0766
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 167.7061 - mae: 9.8196 - val_loss: 97.7855 - val_mae: 8.0660
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 167.1722 - mae: 9.8035 - val_loss: 96.2615 - val_mae: 7.9583
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 145.8379 - mae: 9.2520 - val_loss: 87.5602 - val_mae: 7.5867
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 139.0818 - mae: 8.9373 - val_loss: 76.5715 - val_mae: 7.1418
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 117.4249 - mae: 8.2316 - val_loss: 66.5048 - val_mae: 6.7201
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 116.2638 - mae: 8.0672 - val_loss: 56.1472 - val_mae: 6.2178
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 101.0161 - mae: 7.5389 - val_loss: 48.2602 - val_mae: 5.8064
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 95.8369 - mae: 7.3537 - val_loss: 47.6146 - val_mae: 5.7582
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 80.7293 - mae: 6.8183 - val_loss: 42.8202 - val_mae: 5.4815
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 73.7837 - mae: 6.5615 - val_loss: 41.1956 - val_mae: 5.3624
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 65.4238 - mae: 6.1908 - val_loss: 39.9185 - val_mae: 5.2660
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 61.0535 - mae: 5.9769 - val_loss: 45.5729 - val_mae: 5.5604
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 59.8823 - mae: 5.9429 - val_loss: 25.5063 - val_mae: 4.2389
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 51.1365 - mae: 5.4288 - val_loss: 55.8030 - val_mae: 6.0380
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 54.8348 - mae: 5.6994 - val_loss: 16.7151 - val_mae: 3.4414
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 55.2613 - mae: 5.6470 - val_loss: 37.6545 - val_mae: 5.0482
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 46.2587 - mae: 5.1648 - val_loss: 54.0863 - val_mae: 5.9762
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.6953 - mae: 4.8808 - val_loss: 17.9016 - val_mae: 3.4908
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.0963 - mae: 4.6628 - val_loss: 29.5684 - val_mae: 4.4926
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 38.3179 - mae: 4.6727 - val_loss: 36.9006 - val_mae: 5.0203
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32.1124 - mae: 4.2796 - val_loss: 54.5401 - val_mae: 6.0722
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.8314 - mae: 4.5492 - val_loss: 27.5989 - val_mae: 4.3330
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.4108 - mae: 3.9873 - val_loss: 9.7153 - val_mae: 2.4830
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32.5857 - mae: 4.3207 - val_loss: 24.4514 - val_mae: 4.0520
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 28.4238 - mae: 4.0378 - val_loss: 34.6552 - val_mae: 4.8668
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.6138 - mae: 3.5821 - val_loss: 24.6137 - val_mae: 4.0628
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.4313 - mae: 3.6852 - val_loss: 25.3153 - val_mae: 4.1092
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.6001 - mae: 3.8156 - val_loss: 28.1960 - val_mae: 4.3464
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.0856 - mae: 3.3176 - val_loss: 26.8616 - val_mae: 4.2267
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.1839 - mae: 3.4177 - val_loss: 38.8790 - val_mae: 5.1764
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.9046 - mae: 3.4949 - val_loss: 34.6890 - val_mae: 4.8642
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.0633 - mae: 3.3616 - val_loss: 43.7777 - val_mae: 5.5050
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.7761 - mae: 3.1513 - val_loss: 46.0956 - val_mae: 5.6482
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.9733 - mae: 3.4999 - val_loss: 37.8730 - val_mae: 5.1061
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.4876 - mae: 3.2576 - val_loss: 20.5598 - val_mae: 3.6877
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.3005 - mae: 2.9201 - val_loss: 21.2685 - val_mae: 3.7599
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.6771 - mae: 3.1514 - val_loss: 18.9721 - val_mae: 3.5230
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.6494 - mae: 2.8209 - val_loss: 18.2768 - val_mae: 3.4418
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.1100 - mae: 2.9280 - val_loss: 14.4161 - val_mae: 3.0306
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.6123 - mae: 2.8323 - val_loss: 13.1926 - val_mae: 2.8965
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.2417 - mae: 2.8495 - val_loss: 9.9647 - val_mae: 2.4990
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 17.7028 - mae: 3.2039 - val_loss: 9.5219 - val_mae: 2.4343
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.7370 - mae: 3.1422 - val_loss: 8.8671 - val_mae: 2.3645
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.0239 - mae: 3.2435 - val_loss: 7.6616 - val_mae: 2.1903
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.2204 - mae: 3.0793 - val_loss: 6.6040 - val_mae: 2.0163
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.4535 - mae: 3.5431 - val_loss: 37.1197 - val_mae: 5.0733
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.2627 - mae: 2.9542 - val_loss: 25.7767 - val_mae: 4.1949
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.3117 - mae: 2.8753 - val_loss: 22.9791 - val_mae: 3.9949
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 12.6741 - mae: 2.7508 - val_loss: 9.5738 - val_mae: 2.4868
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.7405 - mae: 2.6174 - val_loss: 12.1845 - val_mae: 2.8236
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.8832 - mae: 2.8730 - val_loss: 12.0561 - val_mae: 2.8142
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.5051 - mae: 2.9148 - val_loss: 17.7146 - val_mae: 3.4861
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.7419 - mae: 2.9055 - val_loss: 26.8321 - val_mae: 4.3462
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.8172 - mae: 2.8803 - val_loss: 29.8480 - val_mae: 4.6094
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.6385 - mae: 2.8863 - val_loss: 12.2805 - val_mae: 2.8538
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.8789 - mae: 2.5655 - val_loss: 8.5218 - val_mae: 2.3452
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.6256 - mae: 3.0426 - val_loss: 14.6203 - val_mae: 3.1564
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.2207 - mae: 2.4832 - val_loss: 33.3255 - val_mae: 4.9052
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.2474 - mae: 2.9104 - val_loss: 14.8456 - val_mae: 3.1877
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.8205 - mae: 2.5391 - val_loss: 16.8494 - val_mae: 3.4089
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.8434 - mae: 2.6425 - val_loss: 13.0595 - val_mae: 2.9802
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.5191 - mae: 2.5534 - val_loss: 8.7031 - val_mae: 2.3746
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.3646 - mae: 2.5250 - val_loss: 10.2055 - val_mae: 2.5967
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.4850 - mae: 2.5758 - val_loss: 17.0582 - val_mae: 3.4609
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9561 - mae: 2.4805 - val_loss: 11.1229 - val_mae: 2.7347
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.4352 - mae: 2.5068 - val_loss: 15.0214 - val_mae: 3.2250
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.8220 - mae: 2.5336 - val_loss: 18.9590 - val_mae: 3.6686
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.3422 - mae: 2.5042 - val_loss: 12.4582 - val_mae: 2.9174
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4155 - mae: 2.4410 - val_loss: 10.0440 - val_mae: 2.5941
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.4549 - mae: 2.5671 - val_loss: 11.3134 - val_mae: 2.7743
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.0779 - mae: 2.4586 - val_loss: 18.7505 - val_mae: 3.6659
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9211 - mae: 2.3013 - val_loss: 11.7938 - val_mae: 2.8403
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.1378 - mae: 2.4555 - val_loss: 13.5866 - val_mae: 3.0750
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.0572 - mae: 2.4909 - val_loss: 10.1755 - val_mae: 2.6276
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.5492 - mae: 2.5815 - val_loss: 8.7516 - val_mae: 2.4130
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0860 - mae: 2.3356 - val_loss: 13.8427 - val_mae: 3.1160
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.8279 - mae: 2.5582 - val_loss: 16.1901 - val_mae: 3.3975
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.5841 - mae: 2.5177 - val_loss: 24.4844 - val_mae: 4.2425
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.6950 - mae: 2.6141 - val_loss: 15.7817 - val_mae: 3.3499
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.0803 - mae: 2.5795 - val_loss: 10.5391 - val_mae: 2.6839
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.3925 - mae: 2.4946 - val_loss: 7.9440 - val_mae: 2.3133
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.6362 - mae: 2.5583 - val_loss: 9.5457 - val_mae: 2.5505
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.4961 - mae: 2.6056 - val_loss: 17.2721 - val_mae: 3.5139
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.4405 - mae: 2.4803 - val_loss: 29.5435 - val_mae: 4.6725
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14.7140 - mae: 2.9175 - val_loss: 19.5553 - val_mae: 3.7573
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.0891 - mae: 2.6598 - val_loss: 13.0414 - val_mae: 3.0257
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.4104 - mae: 2.5426 - val_loss: 7.5459 - val_mae: 2.2542
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.8807 - mae: 2.5272 - val_loss: 19.4972 - val_mae: 3.7676
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.1136 - mae: 2.4585 - val_loss: 11.5737 - val_mae: 2.8433
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9674 - mae: 2.5104 - val_loss: 8.3128 - val_mae: 2.3698
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3747 - mae: 2.3698 - val_loss: 10.3256 - val_mae: 2.6766
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6756 - mae: 2.4208 - val_loss: 14.9154 - val_mae: 3.2704
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1983 - mae: 2.3535 - val_loss: 12.1217 - val_mae: 2.9218
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.3722 - mae: 2.5067 - val_loss: 11.3933 - val_mae: 2.8271
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9128 - mae: 2.4622 - val_loss: 9.6020 - val_mae: 2.5752
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6414 - mae: 2.4386 - val_loss: 10.7170 - val_mae: 2.7427
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5322 - mae: 2.3479 - val_loss: 8.4221 - val_mae: 2.3918
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8712 - mae: 2.2659 - val_loss: 15.3951 - val_mae: 3.3287
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9505 - mae: 2.3104 - val_loss: 9.4378 - val_mae: 2.5563
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1259 - mae: 2.3984 - val_loss: 13.0389 - val_mae: 3.0462
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4383 - mae: 2.4644 - val_loss: 14.6751 - val_mae: 3.2559
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2302 - mae: 2.3761 - val_loss: 16.4749 - val_mae: 3.4659
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.1659 - mae: 2.5408 - val_loss: 10.1528 - val_mae: 2.6674
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7200 - mae: 2.3181 - val_loss: 9.0375 - val_mae: 2.4913
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0267 - mae: 2.3933 - val_loss: 9.6324 - val_mae: 2.5910
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7498 - mae: 2.4426 - val_loss: 12.0533 - val_mae: 2.9293
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2680 - mae: 2.3756 - val_loss: 19.3474 - val_mae: 3.7824
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.1299 - mae: 2.6371 - val_loss: 8.5388 - val_mae: 2.4248
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4379 - mae: 2.4064 - val_loss: 7.2135 - val_mae: 2.2177
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.5209 - mae: 2.5404 - val_loss: 20.7666 - val_mae: 3.9038
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9425 - mae: 2.4717 - val_loss: 14.1920 - val_mae: 3.1963
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.3928 - mae: 2.3626 - val_loss: 8.9374 - val_mae: 2.4881
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.4049 - mae: 2.5471 - val_loss: 7.9431 - val_mae: 2.3451
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4364 - mae: 2.3859 - val_loss: 9.0651 - val_mae: 2.5123
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7414 - mae: 2.2782 - val_loss: 14.9658 - val_mae: 3.2948
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4544 - mae: 2.3030 - val_loss: 8.8191 - val_mae: 2.4724
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9365 - mae: 2.4801 - val_loss: 9.0655 - val_mae: 2.5123
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3513 - mae: 2.4350 - val_loss: 11.1782 - val_mae: 2.8220
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0785 - mae: 2.2265 - val_loss: 10.8785 - val_mae: 2.7782
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7345 - mae: 2.2965 - val_loss: 12.0094 - val_mae: 2.9339
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0017 - mae: 2.3916 - val_loss: 14.0545 - val_mae: 3.1972
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2609 - mae: 2.3739 - val_loss: 16.9433 - val_mae: 3.5341
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.4310 - mae: 2.4637 - val_loss: 6.9612 - val_mae: 2.1730
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.1523 - mae: 2.5763 - val_loss: 6.5379 - val_mae: 2.1151
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.6654 - mae: 2.5400 - val_loss: 16.8703 - val_mae: 3.5190
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3054 - mae: 2.3719 - val_loss: 9.8616 - val_mae: 2.6417
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5879 - mae: 2.2875 - val_loss: 11.2048 - val_mae: 2.8255
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8580 - mae: 2.3549 - val_loss: 9.0247 - val_mae: 2.5165
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4409 - mae: 2.2578 - val_loss: 12.6032 - val_mae: 3.0190
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3234 - mae: 2.2644 - val_loss: 11.8379 - val_mae: 2.9197
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1651 - mae: 2.2577 - val_loss: 9.4084 - val_mae: 2.5745
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4520 - mae: 2.3119 - val_loss: 12.5905 - val_mae: 3.0220
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9114 - mae: 2.3328 - val_loss: 14.1914 - val_mae: 3.2257
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8800 - mae: 2.3247 - val_loss: 9.6272 - val_mae: 2.6083
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5419 - mae: 2.2902 - val_loss: 7.3199 - val_mae: 2.2523
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4606 - mae: 2.3936 - val_loss: 8.1136 - val_mae: 2.3791
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8327 - mae: 2.3207 - val_loss: 11.9363 - val_mae: 2.9294
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1250 - mae: 2.2931 - val_loss: 16.8495 - val_mae: 3.5220
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8240 - mae: 2.4009 - val_loss: 9.7284 - val_mae: 2.6256
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0851 - mae: 2.2312 - val_loss: 7.8487 - val_mae: 2.3318
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0743 - mae: 2.3599 - val_loss: 8.6345 - val_mae: 2.4580
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9944 - mae: 2.3766 - val_loss: 10.7338 - val_mae: 2.7691
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0549 - mae: 2.3482 - val_loss: 19.8986 - val_mae: 3.8629
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8976 - mae: 2.3375 - val_loss: 8.3996 - val_mae: 2.4196
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.7968 - mae: 2.5659 - val_loss: 6.6789 - val_mae: 2.1526
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.0763 - mae: 2.7508 - val_loss: 8.2393 - val_mae: 2.3983
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.6217 - mae: 2.4001 - val_loss: 9.6984 - val_mae: 2.6155
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9344 - mae: 2.4614 - val_loss: 20.7299 - val_mae: 3.9425
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.4679 - mae: 2.6547 - val_loss: 14.2070 - val_mae: 3.2200
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9755 - mae: 2.4343 - val_loss: 8.0880 - val_mae: 2.3795
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3250 - mae: 2.3997 - val_loss: 10.2552 - val_mae: 2.7052
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9000 - mae: 2.3386 - val_loss: 14.0774 - val_mae: 3.2109
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.6633 - mae: 2.5415 - val_loss: 14.0434 - val_mae: 3.2096
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0552 - mae: 2.2661 - val_loss: 10.6787 - val_mae: 2.7702
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.3010 - mae: 2.4239 - val_loss: 6.1469 - val_mae: 2.0550
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.0875 - mae: 2.8032 - val_loss: 6.4169 - val_mae: 2.0846
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.4012 - mae: 2.5948 - val_loss: 21.0155 - val_mae: 3.9758
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.8534 - mae: 2.5587 - val_loss: 16.3371 - val_mae: 3.4639
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9417 - mae: 2.4614 - val_loss: 9.7739 - val_mae: 2.6352
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7437 - mae: 2.1890 - val_loss: 8.1539 - val_mae: 2.3970
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5179 - mae: 2.2484 - val_loss: 11.1432 - val_mae: 2.8328
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7969 - mae: 2.2190 - val_loss: 9.0354 - val_mae: 2.5254
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8444 - mae: 2.2023 - val_loss: 8.0195 - val_mae: 2.3684
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9604 - mae: 2.2020 - val_loss: 17.2803 - val_mae: 3.5921
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2780 - mae: 2.4330 - val_loss: 10.6379 - val_mae: 2.7669
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5421 - mae: 2.1550 - val_loss: 12.7446 - val_mae: 3.0459
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7939 - mae: 2.2224 - val_loss: 9.7574 - val_mae: 2.6424
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9419 - mae: 2.2573 - val_loss: 9.4134 - val_mae: 2.5924
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2128 - mae: 2.2898 - val_loss: 9.5627 - val_mae: 2.6113
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4891 - mae: 2.1816 - val_loss: 11.6237 - val_mae: 2.9050
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2380 - mae: 2.1283 - val_loss: 9.3467 - val_mae: 2.5790
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1118 - mae: 2.2711 - val_loss: 9.1475 - val_mae: 2.5480
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9506 - mae: 2.2291 - val_loss: 8.2678 - val_mae: 2.4136
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8849 - mae: 2.2871 - val_loss: 7.3134 - val_mae: 2.2663
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4747 - mae: 2.4212 - val_loss: 10.5790 - val_mae: 2.7597
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6165 - mae: 2.1788 - val_loss: 11.5352 - val_mae: 2.8897
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9514 - mae: 2.2176 - val_loss: 10.8518 - val_mae: 2.7990
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4165 - mae: 2.3004 - val_loss: 9.1943 - val_mae: 2.5610
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5328 - mae: 2.3535 - val_loss: 9.7035 - val_mae: 2.6380
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3673 - mae: 2.0996 - val_loss: 14.4894 - val_mae: 3.2766
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6355 - mae: 2.1696 - val_loss: 8.4633 - val_mae: 2.4487
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6462 - mae: 2.1795 - val_loss: 11.0481 - val_mae: 2.8302
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7302 - mae: 2.3497 - val_loss: 9.5942 - val_mae: 2.6228
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9991 - mae: 2.2503 - val_loss: 10.8076 - val_mae: 2.7964
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7652 - mae: 2.2218 - val_loss: 8.7876 - val_mae: 2.4995
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ LSTM secuencial guardado en modelo_lstm_semanal.h5
